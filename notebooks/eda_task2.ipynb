# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent.resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root added to path: {PROJECT_ROOT}")
# Out:
# Project root added to path: C:\Users\Administrator\Desktop\10Academy\Week 7\Week7_RAG-complaint-chatbot

# %%
print("=== Task 2: Text Chunking, Embedding, and Vector Store Indexing ===\n")

from src.vector_store_builder import SampleVectorStoreBuilder

# Create and run the builder with 12,000 samples
builder = SampleVectorStoreBuilder(sample_size=12000)
builder.run()

print("\nTask 2 execution completed in the notebook!")
print("Sample vector store is now available at: vector_store/sample_chroma")
print("You can now test retrieval or proceed to Tasks 3–4.")
# Out:
# === Task 2: Text Chunking, Embedding, and Vector Store Indexing ===
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 3
#       1 print("=== Task 2: Text Chunking, Embedding, and Vector Store Indexing ===\n")
# ----> 3 from src.vector_store_builder import SampleVectorStoreBuilder
#       5 # Create and run the builder with 12,000 samples
#       6 builder = SampleVectorStoreBuilder(sample_size=12000)
#
# File ~\Desktop\10Academy\Week 7\Week7_RAG-complaint-chatbot\src\vector_store_builder.py:5
#       3 from langchain_text_splitters import RecursiveCharacterTextSplitter
#       4 from langchain_community.embeddings import HuggingFaceEmbeddings
# ----> 5 from langchain_chroma import Chroma
#       6 from langchain_core.documents import Document
#       7 from pathlib import Path
#
# File c:\Users\Administrator\Desktop\10Academy\Week 7\Week7_RAG-complaint-chatbot\venv\Lib\site-packages\langchain_chroma\__init__.py:3
#       1 """LangChain integration for Chroma vector database."""
# ----> 3 from langchain_chroma.vectorstores import Chroma
#       5 __all__ = [
#       6     "Chroma",
#       7 ]
#
# File c:\Users\Administrator\Desktop\10Academy\Week 7\Week7_RAG-complaint-chatbot\venv\Lib\site-packages\langchain_chroma\vectorstores.py:18
#      12 from pathlib import Path
#      13 from typing import (
#      14     TYPE_CHECKING,
#      15     Any,
#      16 )
# ---> 18 import chromadb
#      19 import chromadb.config
#      20 import numpy as np
#
# ModuleNotFoundError: No module named 'chromadb'
