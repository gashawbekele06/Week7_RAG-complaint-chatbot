# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent.resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root added to path: {PROJECT_ROOT}")
# Out:
# Project root added to path: C:\Users\gasha\OneDrive - Wollo University\Desktop\10Academy Tasks\Week7_RAG-complaint-chatbot

# %%
print("=== Task 2: Text Chunking, Embedding, and Vector Store Indexing ===\n")

from src.vector_store_builder import SampleVectorStoreBuilder

# Create and run the builder with 12,000 samples
builder = SampleVectorStoreBuilder(sample_size=12000)
builder.run()

print("\nTask 2 execution completed in the notebook!")
print("Sample vector store is now available at: vector_store/sample_chroma")
print("You can now test retrieval or proceed to Tasks 3–4.")
# Out:
# === Task 2: Text Chunking, Embedding, and Vector Store Indexing ===
# C:\Users\gasha\OneDrive - Wollo University\Desktop\10Academy Tasks\Week7_RAG-complaint-chatbot\src\vector_store_builder.py:15: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   self.embeddings = HuggingFaceEmbeddings(model_name=self.embedding_model)
# Loading filtered complaints from C:\Users\gasha\OneDrive - Wollo University\Desktop\10Academy Tasks\Week7_RAG-complaint-chatbot\data\processed\filtered_complaints.csv...
# Loaded 407,417 complaints
#
# Creating stratified sample of 12000 complaints...
# C:\Users\gasha\OneDrive - Wollo University\Desktop\10Academy Tasks\Week7_RAG-complaint-chatbot\src\vector_store_builder.py:27: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sample_df = df.groupby('product_category', group_keys=False).apply(
# Sample created: 12000 complaints
# Distribution:
# product_category
# Savings Accounts    4793
# Money Transfers     3220
# Credit Cards        3201
# Personal Loans       786
# Name: count, dtype: int64
#
# Chunking narratives (chunk_size=500, overlap=50)...
# Created 33685 chunks from 12000 complaints
#
# Building vector store with ChromaDB (auto-persistence enabled)...
# Vector store automatically persisted to: C:\Users\gasha\OneDrive - Wollo University\Desktop\10Academy Tasks\Week7_RAG-complaint-chatbot\vector_store\sample_chroma
#
# Task 2 completed successfully!
#
# Task 2 execution completed in the notebook!
# Sample vector store is now available at: vector_store/sample_chroma
# You can now test retrieval or proceed to Tasks 3–4.
